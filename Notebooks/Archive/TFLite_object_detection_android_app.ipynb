# %% [markdown]
# <font size=7> <center> Benchmark - Yolov8 Nano</font></br>

# %% [markdown]
# # 1- Setup

# %%
# This line contains my github token. Please do not share it with anyone
# !git clone https://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@github.com/TKovaks78//Sign_Language_Translation_with_Yolov8.git
# Install requirements
# !pip install -r requirements.txt
# Install Ultralytics
# !pip install ultralytics
# Install clearML
# !pip install clearml
# Check GPU
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.47 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.6/107.7 GB disk)

# %%
# Import libraries
from clearml import Task
from ultralytics import YOLO
import matplotlib.pyplot as plt
from matplotlib.image import imread
import pandas as pd
import os

# %%
# Save models on clearML
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=1XQ9HTBHM5TXCMJCF00W
# %env CLEARML_API_SECRET_KEY=LN6gjflJlyED9HOgyyG3F4G1DMXiRr1FKCi8tXwL7MhSUvMP5e
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=1XQ9HTBHM5TXCMJCF00W
# env: CLEARML_API_SECRET_KEY=LN6gjflJlyED9HOgyyG3F4G1DMXiRr1FKCi8tXwL7MhSUvMP5e

# %% [markdown]
# # 2. Train

# %%
# Define main folder path
path = "/content/Sign_Language_Translation_with_Yolov8"

# Define yaml file path 
yaml_path = os.path.join(path, "data/", "data.yaml")

# Define experience name
exp_name = "benchmark_nano"

project_name = "DL_-_Sign_Detection" # DO NOT CHANGE THE PROJECT NAME

# %%
# Load a model
yolo_model = YOLO("yolov8n.pt")
# Out:
# 2023-02-27 17:27:52,692 - clearml.model - INFO - Selected model id: 1e7f05cd1910454d80a4da4d5e240b97

# %%
task = Task.init(project_name = project_name, # DO NOT CHANGE PROJECT NAME
                 task_name=exp_name) # Name your experience

# %%
# Train the model
yolo_model.train(data= yaml_path,
            project=project_name, 
            epochs=20,   
            name=exp_name)
# Out:
# Ultralytics YOLOv8.0.47 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/Sign_Language_Translation_with_Yolov8/data/data.yaml, epochs=20, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=DL_-_Sign_Detection, name=benchmark_nano, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, min_memory=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=DL_-_Sign_Detection/benchmark_nano
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# Overriding model.yaml nc=80 with nc=26
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    756382  ultralytics.nn.modules.Detect                [26, [64, 128, 256]]
# Model summary: 225 layers, 3015918 parameters, 3015902 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /content/Sign_Language_Translation_with_Yolov8/data/train/labels... 508 images, 0 backgrounds, 0 corrupt: 100%|██████████| 508/508 [00:00<00:00, 1159.10it/s]
# train: New cache created: /content/Sign_Language_Translation_with_Yolov8/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning:
#
# Can't initialize NVML
#
# val: Scanning /content/Sign_Language_Translation_with_Yolov8/data/valid/labels... 104 images, 0 backgrounds, 0 corrupt: 100%|██████████| 104/104 [00:00<00:00, 476.31it/s]
# val: New cache created: /content/Sign_Language_Translation_with_Yolov8/data/valid/labels.cache
# Plotting labels to DL_-_Sign_Detection/benchmark_nano/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to DL_-_Sign_Detection/benchmark_nano
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20         0G     0.9646       4.48      1.417         21        640: 100%|██████████| 32/32 [07:10<00:00, 13.46s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:32<00:00,  8.09s/it]
#                    all        104        104          0          0          0          0
# 2023-02-27 16:48:05,572 - clearml.frameworks - INFO - Found existing registered model id=b0c4a01e391d4cff949cc57c82b9daba [/content/DL_-_Sign_Detection/benchmark_nano/weights/last.pt] reusing it.
# 2023-02-27 16:48:07,539 - clearml.frameworks - INFO - Found existing registered model id=a7e5a9615adf4ba2917b6f745f961085 [/content/DL_-_Sign_Detection/benchmark_nano/weights/best.pt] reusing it.
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20         0G     0.8374      4.172      1.304         33        640: 100%|██████████| 32/32 [07:08<00:00, 13.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:28<00:00,  7.17s/it]
#                    all        104        104     0.0216      0.393     0.0703     0.0405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20         0G     0.9075      3.913      1.348         30        640: 100%|██████████| 32/32 [06:41<00:00, 12.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:29<00:00,  7.49s/it]
#                    all        104        104      0.659      0.114      0.158      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20         0G     0.9671      3.692      1.385         31        640: 100%|██████████| 32/32 [06:44<00:00, 12.63s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:28<00:00,  7.23s/it]
#                    all        104        104      0.214      0.228      0.109     0.0613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20         0G      0.979      3.361      1.359         20        640: 100%|██████████| 32/32 [06:43<00:00, 12.60s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:29<00:00,  7.29s/it]
#                    all        104        104      0.136      0.266      0.141     0.0907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20         0G     0.9747      3.273      1.376         15        640: 100%|██████████| 32/32 [06:40<00:00, 12.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:28<00:00,  7.15s/it]
#                    all        104        104      0.318      0.481      0.313      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20         0G     0.9163      3.137      1.313         25        640:  41%|████      | 13/32 [02:52<04:11, 13.25s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1637377a881e> in <module>
#       1 # Train the model
# ----> 2 yolo_model.train(data= yaml_path,
#       3             project=project_name,
#       4             epochs=20,
#       5             name=exp_name)
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     315             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     316             self.model = self.trainer.model
# --> 317         self.trainer.train()
#     318         # update model and cfg after training
#     319         if RANK in {0, -1}:
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/trainer.py in train(self)
#     186                 ddp_cleanup(self, str(file))
#     187         else:
# --> 188             self._do_train(RANK, world_size)
#     189
#     190     def _setup_ddp(self, rank, world_size):
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/yolo/engine/trainer.py in _do_train(self, rank, world_size)
#     306                 with torch.cuda.amp.autocast(self.amp):
#     307                     batch = self.preprocess_batch(batch)
# --> 308                     preds = self.model(batch['img'])
#     309                     self.loss, self.loss_items = self.criterion(preds, batch)
#     310                     if rank != -1:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/tasks.py in forward(self, x, augment, profile, visualize)
#     197         if augment:
#     198             return self._forward_augment(x)  # augmented inference, None
# --> 199         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     200
#     201     def _forward_augment(self, x):
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/tasks.py in _forward_once(self, x, profile, visualize)
#      56             if profile:
#      57                 self._profile_one_layer(m, x, dt)
# ---> 58             x = m(x)  # run
#      59             y.append(x if m.i in self.save else None)  # save output
#      60             if visualize:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/modules.py in forward(self, x)
#     189
#     190     def forward(self, x):
# --> 191         y = list(self.cv1(x).chunk(2, 1))
#     192         y.extend(m(y[-1]) for m in self.m)
#     193         return self.cv2(torch.cat(y, 1))
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/ultralytics/nn/modules.py in forward(self, x)
#      32
#      33     def forward(self, x):
# ---> 34         return self.act(self.bn(self.conv(x)))
#      35
#      36     def forward_fuse(self, x):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     169         used for normalization (i.e. in eval mode when buffers are not None).
#     170         """
# --> 171         return F.batch_norm(
#     172             input,
#     173             # If buffers are not to be tracked, ensure that they won't be updated
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2448         _verify_batch_size(input.size())
#    2449
# -> 2450     return torch.batch_norm(
#    2451         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2452     )
#
# KeyboardInterrupt:

# %% [markdown]
# <font size =2><u>Note:</u> to change any parameter you just have to add parameter_name=value. The only mandatory parameter is data</br>
# For example:
#
# ```
# # Train the model
# results_baseline = model.train(data= yaml_path,
#                               momentum = 0.9
#                               lrf = 0.0001)
# ```
# <font size =2>Please refer to the [configuration file](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/yolo/cfg/default.yaml)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# perform inference on each image from the split up video
infer = YOLO("/content/DL_-_Sign_Detection/benchmark_nano/weights/best.pt")
# %cd /content/inferred_videos
infer.predict("/content/drive/MyDrive/videos_to_infer/vid.mp4", save=True, save_txt=True)
# Out:
# Ultralytics YOLOv8.0.47 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Model summary (fused): 168 layers, 3010718 parameters, 0 gradients, 8.1 GFLOPs
# [Errno 2] No such file or directory: '/content/inferred_videos'
# /content
# video 1/1 (1/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.8ms
# video 1/1 (2/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 148.9ms
# video 1/1 (3/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 539.4ms
# video 1/1 (4/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 243.3ms
# video 1/1 (5/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 556.9ms
# video 1/1 (6/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 607.5ms
# video 1/1 (7/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 265.5ms
# video 1/1 (8/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 242.1ms
# video 1/1 (9/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 295.0ms
# video 1/1 (10/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 248.3ms
# video 1/1 (11/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 237.8ms
# video 1/1 (12/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 224.6ms
# video 1/1 (13/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 233.1ms
# video 1/1 (14/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 213.6ms
# video 1/1 (15/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 248.6ms
# video 1/1 (16/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 216.1ms
# video 1/1 (17/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 199.9ms
# video 1/1 (18/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 209.4ms
# video 1/1 (19/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 216.0ms
# video 1/1 (20/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.4ms
# video 1/1 (21/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 226.4ms
# video 1/1 (22/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 211.1ms
# video 1/1 (23/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.3ms
# video 1/1 (24/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.2ms
# video 1/1 (25/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.6ms
# video 1/1 (26/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.4ms
# video 1/1 (27/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.9ms
# video 1/1 (28/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.1ms
# video 1/1 (29/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 120.1ms
# video 1/1 (30/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.0ms
# video 1/1 (31/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.9ms
# video 1/1 (32/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.0ms
# video 1/1 (33/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.4ms
# video 1/1 (34/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.0ms
# video 1/1 (35/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.7ms
# video 1/1 (36/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.4ms
# video 1/1 (37/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.9ms
# video 1/1 (38/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.2ms
# video 1/1 (39/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.2ms
# video 1/1 (40/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.0ms
# video 1/1 (41/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.6ms
# video 1/1 (42/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.3ms
# video 1/1 (43/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.2ms
# video 1/1 (44/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.2ms
# video 1/1 (45/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.5ms
# video 1/1 (46/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 144.7ms
# video 1/1 (47/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.5ms
# video 1/1 (48/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.5ms
# video 1/1 (49/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.4ms
# video 1/1 (50/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 121.7ms
# video 1/1 (51/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.2ms
# video 1/1 (52/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.0ms
# video 1/1 (53/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 148.4ms
# video 1/1 (54/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 156.3ms
# video 1/1 (55/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.6ms
# video 1/1 (56/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.1ms
# video 1/1 (57/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.3ms
# video 1/1 (58/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.4ms
# video 1/1 (59/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.2ms
# video 1/1 (60/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.0ms
# video 1/1 (61/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.9ms
# video 1/1 (62/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.3ms
# video 1/1 (63/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.4ms
# video 1/1 (64/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 120.6ms
# video 1/1 (65/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.7ms
# video 1/1 (66/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.6ms
# video 1/1 (67/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.8ms
# video 1/1 (68/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 153.5ms
# video 1/1 (69/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 141.5ms
# video 1/1 (70/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.1ms
# video 1/1 (71/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 120.3ms
# video 1/1 (72/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.2ms
# video 1/1 (73/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.9ms
# video 1/1 (74/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.0ms
# video 1/1 (75/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.1ms
# video 1/1 (76/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.5ms
# video 1/1 (77/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.7ms
# video 1/1 (78/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 120.0ms
# video 1/1 (79/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.2ms
# video 1/1 (80/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.0ms
# video 1/1 (81/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.3ms
# video 1/1 (82/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.8ms
# video 1/1 (83/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.7ms
# video 1/1 (84/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.7ms
# video 1/1 (85/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.8ms
# video 1/1 (86/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.3ms
# video 1/1 (87/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.6ms
# video 1/1 (88/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.5ms
# video 1/1 (89/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.5ms
# video 1/1 (90/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 143.7ms
# video 1/1 (91/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.8ms
# video 1/1 (92/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.5ms
# video 1/1 (93/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 120.8ms
# video 1/1 (94/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 213.0ms
# video 1/1 (95/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 201.4ms
# video 1/1 (96/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 222.4ms
# video 1/1 (97/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 235.1ms
# video 1/1 (98/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.0ms
# video 1/1 (99/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.8ms
# video 1/1 (100/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 202.5ms
# video 1/1 (101/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.3ms
# video 1/1 (102/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 198.4ms
# video 1/1 (103/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 225.6ms
# video 1/1 (104/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 201.3ms
# video 1/1 (105/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 204.8ms
# video 1/1 (106/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 202.1ms
# video 1/1 (107/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 263.0ms
# video 1/1 (108/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 213.8ms
# video 1/1 (109/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 209.6ms
# video 1/1 (110/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 203.8ms
# video 1/1 (111/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 198.6ms
# video 1/1 (112/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 194.7ms
# video 1/1 (113/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 204.3ms
# video 1/1 (114/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 198.6ms
# video 1/1 (115/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.3ms
# video 1/1 (116/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 195.2ms
# video 1/1 (117/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 222.0ms
# video 1/1 (118/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 161.2ms
# video 1/1 (119/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.3ms
# video 1/1 (120/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.9ms
# video 1/1 (121/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.3ms
# video 1/1 (122/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.8ms
# video 1/1 (123/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.6ms
# video 1/1 (124/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.1ms
# video 1/1 (125/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.8ms
# video 1/1 (126/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.9ms
# video 1/1 (127/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.9ms
# video 1/1 (128/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 151.3ms
# video 1/1 (129/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.8ms
# video 1/1 (130/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.3ms
# video 1/1 (131/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.6ms
# video 1/1 (132/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.9ms
# video 1/1 (133/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 146.9ms
# video 1/1 (134/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.0ms
# video 1/1 (135/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.6ms
# video 1/1 (136/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 124.0ms
# video 1/1 (137/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 135.5ms
# video 1/1 (138/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 127.0ms
# video 1/1 (139/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 133.1ms
# video 1/1 (140/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 133.1ms
# video 1/1 (141/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 126.8ms
# video 1/1 (142/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 138.9ms
# video 1/1 (143/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 128.5ms
# video 1/1 (144/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 131.6ms
# video 1/1 (145/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 132.7ms
# video 1/1 (146/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 T, 139.8ms
# video 1/1 (147/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 149.2ms
# video 1/1 (148/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 128.4ms
# video 1/1 (149/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 T, 139.7ms
# video 1/1 (150/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 T, 128.7ms
# video 1/1 (151/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 T, 125.9ms
# video 1/1 (152/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 T, 126.4ms
# video 1/1 (153/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 134.5ms
# video 1/1 (154/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 136.5ms
# video 1/1 (155/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 123.9ms
# video 1/1 (156/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 131.3ms
# video 1/1 (157/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 121.4ms
# video 1/1 (158/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 132.2ms
# video 1/1 (159/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 129.9ms
# video 1/1 (160/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 127.1ms
# video 1/1 (161/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 135.8ms
# video 1/1 (162/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 158.4ms
# video 1/1 (163/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 141.5ms
# video 1/1 (164/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 133.8ms
# video 1/1 (165/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 127.9ms
# video 1/1 (166/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 138.8ms
# video 1/1 (167/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 128.3ms
# video 1/1 (168/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 125.3ms
# video 1/1 (169/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 126.7ms
# video 1/1 (170/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 127.0ms
# video 1/1 (171/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 126.5ms
# video 1/1 (172/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 132.5ms
# video 1/1 (173/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 132.7ms
# video 1/1 (174/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 130.8ms
# video 1/1 (175/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 124.3ms
# video 1/1 (176/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 134.4ms
# video 1/1 (177/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 135.9ms
# video 1/1 (178/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 147.3ms
# video 1/1 (179/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 128.6ms
# video 1/1 (180/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 123.9ms
# video 1/1 (181/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 T, 126.3ms
# video 1/1 (182/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 131.9ms
# video 1/1 (183/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 132.2ms
# video 1/1 (184/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 125.7ms
# video 1/1 (185/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 T, 144.4ms
# video 1/1 (186/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 T, 128.8ms
# video 1/1 (187/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 T, 170.6ms
# video 1/1 (188/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 T, 206.2ms
# video 1/1 (189/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 T, 207.5ms
# video 1/1 (190/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 S, 276.0ms
# video 1/1 (191/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 S, 213.7ms
# video 1/1 (192/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 T, 214.8ms
# video 1/1 (193/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 S, 201.7ms
# video 1/1 (194/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 S, 203.0ms
# video 1/1 (195/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 2 Ms, 1 S, 210.9ms
# video 1/1 (196/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 1 T, 211.4ms
# video 1/1 (197/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 210.9ms
# video 1/1 (198/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 221.3ms
# video 1/1 (199/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 1 T, 233.7ms
# video 1/1 (200/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 607.8ms
# video 1/1 (201/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 440.2ms
# video 1/1 (202/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 229.7ms
# video 1/1 (203/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 543.9ms
# video 1/1 (204/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 516.6ms
# video 1/1 (205/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 173.6ms
# video 1/1 (206/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 139.4ms
# video 1/1 (207/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 141.5ms
# video 1/1 (208/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 228.5ms
# video 1/1 (209/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 331.5ms
# video 1/1 (210/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 131.6ms
# video 1/1 (211/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 2 Ms, 1 S, 129.4ms
# video 1/1 (212/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 129.0ms
# video 1/1 (213/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 194.1ms
# video 1/1 (214/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 T, 426.3ms
# video 1/1 (215/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 T, 126.9ms
# video 1/1 (216/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 1 S, 133.5ms
# video 1/1 (217/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 1 S, 1 T, 130.8ms
# video 1/1 (218/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 A, 1 M, 443.9ms
# video 1/1 (219/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 129.5ms
# video 1/1 (220/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.0ms
# video 1/1 (221/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 M, 127.7ms
# video 1/1 (222/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.0ms
# video 1/1 (223/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.9ms
# video 1/1 (224/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.9ms
# video 1/1 (225/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.8ms
# video 1/1 (226/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.3ms
# video 1/1 (227/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.7ms
# video 1/1 (228/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.5ms
# video 1/1 (229/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.2ms
# video 1/1 (230/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.3ms
# video 1/1 (231/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.5ms
# video 1/1 (232/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 141.0ms
# video 1/1 (233/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.4ms
# video 1/1 (234/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.6ms
# video 1/1 (235/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.3ms
# video 1/1 (236/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 146.0ms
# video 1/1 (237/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.1ms
# video 1/1 (238/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.8ms
# video 1/1 (239/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.7ms
# video 1/1 (240/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.5ms
# video 1/1 (241/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.4ms
# video 1/1 (242/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 143.1ms
# video 1/1 (243/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.2ms
# video 1/1 (244/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.6ms
# video 1/1 (245/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.8ms
# video 1/1 (246/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.0ms
# video 1/1 (247/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.9ms
# video 1/1 (248/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.8ms
# video 1/1 (249/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.3ms
# video 1/1 (250/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 148.5ms
# video 1/1 (251/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.5ms
# video 1/1 (252/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.6ms
# video 1/1 (253/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.9ms
# video 1/1 (254/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.2ms
# video 1/1 (255/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.2ms
# video 1/1 (256/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.7ms
# video 1/1 (257/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 148.1ms
# video 1/1 (258/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.2ms
# video 1/1 (259/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.0ms
# video 1/1 (260/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.2ms
# video 1/1 (261/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.0ms
# video 1/1 (262/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.3ms
# video 1/1 (263/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.7ms
# video 1/1 (264/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.7ms
# video 1/1 (265/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 125.5ms
# video 1/1 (266/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 124.9ms
# video 1/1 (267/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 123.4ms
# video 1/1 (268/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 183.5ms
# video 1/1 (269/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 197.6ms
# video 1/1 (270/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 258.4ms
# video 1/1 (271/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 216.9ms
# video 1/1 (272/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 213.6ms
# video 1/1 (273/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 213.4ms
# video 1/1 (274/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 217.2ms
# video 1/1 (275/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 201.6ms
# video 1/1 (276/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 204.1ms
# video 1/1 (277/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 200.2ms
# video 1/1 (278/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 207.9ms
# video 1/1 (279/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 226.7ms
# video 1/1 (280/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 250.0ms
# video 1/1 (281/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 211.2ms
# video 1/1 (282/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 205.0ms
# video 1/1 (283/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 201.4ms
# video 1/1 (284/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 206.2ms
# video 1/1 (285/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 206.6ms
# video 1/1 (286/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 208.8ms
# video 1/1 (287/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 204.5ms
# video 1/1 (288/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 211.2ms
# video 1/1 (289/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 219.0ms
# video 1/1 (290/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 223.7ms
# video 1/1 (291/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 217.0ms
# video 1/1 (292/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 123.3ms
# video 1/1 (293/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 V, 1 W, 134.5ms
# video 1/1 (294/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 126.7ms
# video 1/1 (295/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 139.7ms
# video 1/1 (296/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 125.2ms
# video 1/1 (297/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 W, 151.2ms
# video 1/1 (298/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.3ms
# video 1/1 (299/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.9ms
# video 1/1 (300/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.5ms
# video 1/1 (301/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.3ms
# video 1/1 (302/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 148.0ms
# video 1/1 (303/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 145.6ms
# video 1/1 (304/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.2ms
# video 1/1 (305/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.7ms
# video 1/1 (306/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.1ms
# video 1/1 (307/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 144.0ms
# video 1/1 (308/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.4ms
# video 1/1 (309/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.0ms
# video 1/1 (310/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.2ms
# video 1/1 (311/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.1ms
# video 1/1 (312/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.5ms
# video 1/1 (313/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.5ms
# video 1/1 (314/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.5ms
# video 1/1 (315/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 153.6ms
# video 1/1 (316/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 142.8ms
# video 1/1 (317/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 142.3ms
# video 1/1 (318/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 155.4ms
# video 1/1 (319/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.8ms
# video 1/1 (320/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.6ms
# video 1/1 (321/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.7ms
# video 1/1 (322/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.8ms
# video 1/1 (323/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 141.5ms
# video 1/1 (324/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.4ms
# video 1/1 (325/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.3ms
# video 1/1 (326/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.8ms
# video 1/1 (327/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.5ms
# video 1/1 (328/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 142.7ms
# video 1/1 (329/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.2ms
# video 1/1 (330/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.5ms
# video 1/1 (331/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 144.2ms
# video 1/1 (332/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 150.3ms
# video 1/1 (333/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 142.9ms
# video 1/1 (334/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.1ms
# video 1/1 (335/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.3ms
# video 1/1 (336/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.2ms
# video 1/1 (337/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.6ms
# video 1/1 (338/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.4ms
# video 1/1 (339/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.5ms
# video 1/1 (340/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.5ms
# video 1/1 (341/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.3ms
# video 1/1 (342/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.1ms
# video 1/1 (343/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.6ms
# video 1/1 (344/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 145.2ms
# video 1/1 (345/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.6ms
# video 1/1 (346/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.6ms
# video 1/1 (347/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 161.9ms
# video 1/1 (348/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 151.3ms
# video 1/1 (349/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.8ms
# video 1/1 (350/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 150.1ms
# video 1/1 (351/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.1ms
# video 1/1 (352/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.8ms
# video 1/1 (353/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.2ms
# video 1/1 (354/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.3ms
# video 1/1 (355/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.9ms
# video 1/1 (356/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.6ms
# video 1/1 (357/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.9ms
# video 1/1 (358/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.8ms
# video 1/1 (359/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.7ms
# video 1/1 (360/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.9ms
# video 1/1 (361/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 205.3ms
# video 1/1 (362/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 239.8ms
# video 1/1 (363/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 226.3ms
# video 1/1 (364/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 215.5ms
# video 1/1 (365/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 209.0ms
# video 1/1 (366/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 209.8ms
# video 1/1 (367/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 210.7ms
# video 1/1 (368/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 207.3ms
# video 1/1 (369/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 203.0ms
# video 1/1 (370/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 204.0ms
# video 1/1 (371/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 203.2ms
# video 1/1 (372/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 252.6ms
# video 1/1 (373/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 215.8ms
# video 1/1 (374/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 210.7ms
# video 1/1 (375/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 203.0ms
# video 1/1 (376/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 200.4ms
# video 1/1 (377/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 215.0ms
# video 1/1 (378/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 216.3ms
# video 1/1 (379/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 212.6ms
# video 1/1 (380/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 196.8ms
# video 1/1 (381/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 250.2ms
# video 1/1 (382/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 213.7ms
# video 1/1 (383/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 213.2ms
# video 1/1 (384/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 208.9ms
# video 1/1 (385/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 180.5ms
# video 1/1 (386/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.9ms
# video 1/1 (387/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.2ms
# video 1/1 (388/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 123.5ms
# video 1/1 (389/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 159.4ms
# video 1/1 (390/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 445.1ms
# video 1/1 (391/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 150.1ms
# video 1/1 (392/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 145.3ms
# video 1/1 (393/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 181.5ms
# video 1/1 (394/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 572.9ms
# video 1/1 (395/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 145.2ms
# video 1/1 (396/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.3ms
# video 1/1 (397/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 150.3ms
# video 1/1 (398/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.3ms
# video 1/1 (399/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.9ms
# video 1/1 (400/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.4ms
# video 1/1 (401/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.5ms
# video 1/1 (402/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.1ms
# video 1/1 (403/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.7ms
# video 1/1 (404/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 159.5ms
# video 1/1 (405/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 155.4ms
# video 1/1 (406/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.9ms
# video 1/1 (407/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 135.3ms
# video 1/1 (408/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.4ms
# video 1/1 (409/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.4ms
# video 1/1 (410/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.0ms
# video 1/1 (411/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.9ms
# video 1/1 (412/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 125.3ms
# video 1/1 (413/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.3ms
# video 1/1 (414/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 143.6ms
# video 1/1 (415/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.2ms
# video 1/1 (416/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.4ms
# video 1/1 (417/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.1ms
# video 1/1 (418/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.8ms
# video 1/1 (419/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.1ms
# video 1/1 (420/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.1ms
# video 1/1 (421/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.0ms
# video 1/1 (422/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.2ms
# video 1/1 (423/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 137.2ms
# video 1/1 (424/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.0ms
# video 1/1 (425/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.2ms
# video 1/1 (426/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.5ms
# video 1/1 (427/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.4ms
# video 1/1 (428/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 128.9ms
# video 1/1 (429/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 140.0ms
# video 1/1 (430/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.4ms
# video 1/1 (431/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.4ms
# video 1/1 (432/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 147.3ms
# video 1/1 (433/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 127.1ms
# video 1/1 (434/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 136.2ms
# video 1/1 (435/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 150.3ms
# video 1/1 (436/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.2ms
# video 1/1 (437/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.6ms
# video 1/1 (438/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.4ms
# video 1/1 (439/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 121.3ms
# video 1/1 (440/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 132.2ms
# video 1/1 (441/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 122.7ms
# video 1/1 (442/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 138.8ms
# video 1/1 (443/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 129.1ms
# video 1/1 (444/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.9ms
# video 1/1 (445/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 126.1ms
# video 1/1 (446/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.5ms
# video 1/1 (447/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 139.0ms
# video 1/1 (448/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 124.9ms
# video 1/1 (449/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 182.0ms
# video 1/1 (450/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 B, 227.9ms
# video 1/1 (451/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 B, 211.6ms
# video 1/1 (452/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 B, 214.6ms
# video 1/1 (453/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 B, 208.7ms
# video 1/1 (454/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 1 B, 217.0ms
# video 1/1 (455/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 210.0ms
# video 1/1 (456/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.1ms
# video 1/1 (457/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 223.0ms
# video 1/1 (458/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 210.5ms
# video 1/1 (459/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 221.3ms
# video 1/1 (460/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 207.4ms
# video 1/1 (461/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 222.4ms
# video 1/1 (462/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 215.1ms
# video 1/1 (463/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 205.6ms
# video 1/1 (464/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.7ms
# video 1/1 (465/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 211.9ms
# video 1/1 (466/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 218.0ms
# video 1/1 (467/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 208.4ms
# video 1/1 (468/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 219.7ms
# video 1/1 (469/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 237.3ms
# video 1/1 (470/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 207.7ms
# video 1/1 (471/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 224.6ms
# video 1/1 (472/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 206.4ms
# video 1/1 (473/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 144.9ms
# video 1/1 (474/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 133.3ms
# video 1/1 (475/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 131.0ms
# video 1/1 (476/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 130.0ms
# video 1/1 (477/2934) /content/drive/MyDrive/videos_to_infer/vid.mp4: 384x640 (no detections), 134.8ms
# ...
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[4.90000e+01, 2.54000e+02, 1.50000e+02, 3.47000e+02, 3.10885e-01, 2.50000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 254.00000, 150.00000, 349.00000,   0.37879,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 254.00000, 149.00000, 350.00000,   0.43117,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 254.00000, 148.00000, 350.00000,   0.48151,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 254.00000, 148.00000, 350.00000,   0.48159,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 254.00000, 147.00000, 350.00000,   0.46995,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 255.00000, 146.00000, 349.00000,   0.46257,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 349.00000,   0.48382,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 351.00000,   0.52596,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 351.00000,   0.53675,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 351.00000,   0.52320,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 350.00000,   0.51462,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 350.00000,   0.51638,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 349.00000,   0.49126,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 349.00000,   0.50361,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 349.00000,   0.50558,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 348.00000,   0.48071,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 347.00000,   0.43427,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 347.00000,   0.42719,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 348.00000,   0.40674,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.40119,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.39920,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.38791,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.39883,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.39638,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 348.00000,   0.40307,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 256.00000, 145.00000, 349.00000,   0.41084,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 256.00000, 145.00000, 348.00000,   0.38650,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 256.00000, 145.00000, 348.00000,   0.42181,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 256.00000, 145.00000, 347.00000,   0.43416,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 346.00000,   0.39268,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 347.00000,   0.39211,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 255.00000, 145.00000, 345.00000,   0.37477,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 345.00000,   0.37963,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 345.00000,   0.37623,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 345.00000,   0.39353,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 255.00000, 145.00000, 345.00000,   0.38867,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.37624,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.39839,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.39350,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.37702,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.39116,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.38838,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 255.00000, 145.00000, 345.00000,   0.41212,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 254.00000, 145.00000, 345.00000,   0.44637,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 254.00000, 145.00000, 345.00000,   0.46056,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 254.00000, 145.00000, 345.00000,   0.47990,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 254.00000, 145.00000, 345.00000,   0.47576,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 45.00000, 254.00000, 145.00000, 345.00000,   0.48045,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 45.00000, 254.00000, 145.00000, 345.00000,   0.48014,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 45.00000, 254.00000, 145.00000, 345.00000,   0.49043,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 45.00000, 254.00000, 145.00000, 345.00000,   0.46115,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 46.00000, 254.00000, 145.00000, 345.00000,   0.46623,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 345.00000,   0.42863,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 254.00000, 145.00000, 344.00000,   0.37788,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[4.80000e+01, 2.54000e+02, 1.45000e+02, 3.42000e+02, 2.97741e-01, 2.50000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 48.00000, 252.00000, 144.00000, 348.00000,   0.35136,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 49.00000, 252.00000, 146.00000, 341.00000,   0.47588,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 50.00000, 252.00000, 146.00000, 341.00000,   0.36871,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[5.10000e+01, 2.52000e+02, 1.45000e+02, 3.51000e+02, 3.28759e-01, 2.50000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[5.10000e+01, 2.52000e+02, 1.44000e+02, 3.38000e+02, 2.80130e-01, 2.50000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000, 251.00000, 138.00000, 333.00000,   0.49887,  25.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([0, 6])
#  dtype: torch.float32
#   + tensor([], size=(0, 6)),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[4.60000e+01, 2.46000e+02, 1.35000e+02, 3.36000e+02, 2.81834e-01, 2.50000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[4.20000e+01, 2.47000e+02, 1.40000e+02, 3.37000e+02, 3.23511e-01, 2.50000e+01],
#          [3.90000e+01, 2.43000e+02, 1.44000e+02, 3.41000e+02, 2.55052e-01, 1.20000e+01]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([0, 6])
#  dtype: torch.float32
#   + tensor([], size=(0, 6)),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[ 50.00000,  49.00000, 173.00000, 149.00000,   0.75346,  12.00000],
#          [ 53.00000,  55.00000, 171.00000, 147.00000,   0.25080,  18.00000]]),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 47.00000,  46.00000, 174.00000, 149.00000,   0.70068,  12.00000]]),
#  ...]

# %% [markdown]
# # 3. Results

# %%
# Loss
img = imread(os.path.join(project_name, exp_name, "results.png"))
plt.figure(figsize=(14,12))
plt.imshow(img)
plt.show()

# %%
# Confusion matrix
img = imread(os.path.join(project_name, exp_name,"confusion_matrix.png"))
plt.figure(figsize=(14,12))
plt.imshow(img)
plt.show()

# %%
# top mAP50-95 score
df = pd.read_csv(os.path.join(project_name, exp_name,"results.csv"))
max_map50_index = df['    metrics/mAP50-95(B)'].idxmax()
result = df.loc[max_map50_index]
result
# Out:
#                   epoch    19.00000
#          train/box_loss     0.48493
#          train/cls_loss     1.69820
#          train/dfl_loss     1.02960
#    metrics/precision(B)     0.77938
#       metrics/recall(B)     0.87625
#        metrics/mAP50(B)     0.91756
#     metrics/mAP50-95(B)     0.82281
#            val/box_loss     0.51477
#            val/cls_loss     1.01760
#            val/dfl_loss     1.07130
#                  lr/pg0     0.00109
#                  lr/pg1     0.00109
#                  lr/pg2     0.00109
# Name: 19, dtype: float64

# %%
# Way around to avoid error when saving results
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# Save results
# Write your experience name
from google.colab import files
# !zip -r results.zip /content/DL_-_Sign_Detection/benchmark_nano
files.download("results.zip")
# Out:
#   adding: content/DL_-_Sign_Detection/benchmark_nano/ (stored 0%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch0_labels.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/R_curve.png (deflated 6%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch2.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/results.png (deflated 7%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/results.csv (deflated 83%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/P_curve.png (deflated 6%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch321.jpg (deflated 8%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/confusion_matrix.png (deflated 15%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/F1_curve.png (deflated 5%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/PR_curve.png (deflated 18%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch1_pred.jpg (deflated 10%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch0.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch2_pred.jpg (deflated 12%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch0_pred.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch1.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/args.yaml (deflated 50%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch2_labels.jpg (deflated 12%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch320.jpg (deflated 11%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/events.out.tfevents.1677149785.5b82de039848.632.0 (deflated 71%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/weights/ (stored 0%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/weights/best.pt (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/weights/last.pt (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/val_batch1_labels.jpg (deflated 10%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/train_batch322.jpg (deflated 13%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/labels_correlogram.jpg (deflated 33%)
#   adding: content/DL_-_Sign_Detection/benchmark_nano/labels.jpg (deflated 29%)

# %%
# !python export.py --weights /content/DL_-_Sign_Detection/benchmark_nano/weights/best.pt --include tflite --img 640
# Out:
# python3: can't open file 'task=': [Errno 2] No such file or directory

# %%
# !yolo task=detect mode=export model=yolov8n.pt format=tflite source=/content/DL_-_Sign_Detection/benchmark_nano/weights/best.pt
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from yolov8n.pt with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# WARNING ⚠️ YOLOv8 TensorFlow export is still under development. Please consider contributing to the effort if you have TF expertise. Thank you!
# 2023-02-23 11:26:54.848689: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-02-23 11:26:54.848843: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-02-23 11:26:54.848863: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# requirements: YOLOv8 requirements "onnx" "onnx2tf" "sng4onnx" "onnxsim" "onnx_graphsurgeon" "tflite_support" "onnxruntime" not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://pypi.ngc.nvidia.com
# Collecting onnx
#   Downloading onnx-1.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 86.0 MB/s eta 0:00:00
# Collecting onnx2tf
#   Downloading onnx2tf-1.7.4-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 KB 32.7 MB/s eta 0:00:00
# Collecting sng4onnx
#   Downloading sng4onnx-1.0.1-py3-none-any.whl (5.8 kB)
# Collecting onnxsim
#   Downloading onnxsim-0.4.17-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 84.2 MB/s eta 0:00:00
# Collecting onnx_graphsurgeon
#   Downloading https://developer.download.nvidia.com/compute/redist/onnx-graphsurgeon/onnx_graphsurgeon-0.3.26-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 KB 5.1 MB/s eta 0:00:00
# Collecting tflite_support
#   Downloading tflite_support-0.4.3-cp38-cp38-manylinux2014_x86_64.whl (60.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 MB 20.3 MB/s eta 0:00:00
# Collecting onnxruntime
#   Downloading onnxruntime-1.14.0-cp38-cp38-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 108.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx) (4.5.0)
# Collecting protobuf<4,>=3.20.2
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx) (1.22.4)
# Collecting rich
#   Downloading rich-13.3.1-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tflite_support) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tflite_support) (23.1.21)
# Collecting pybind11>=2.6.0
#   Downloading pybind11-2.10.3-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 KB 24.5 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4
#   Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from onnxruntime) (1.7.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from onnxruntime) (23.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.8/dist-packages (from sounddevice>=0.4.4->tflite_support) (1.15.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 11.8 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.14.0
#   Downloading Pygments-2.14.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.4 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.1.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->onnxruntime) (1.2.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->tflite_support) (2.21)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: sng4onnx, pygments, pybind11, protobuf, onnx2tf, mdurl, humanfriendly, sounddevice, onnx, markdown-it-py, coloredlogs, tflite_support, rich, onnxruntime, onnx_graphsurgeon, onnxsim
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.6.1
#     Uninstalling Pygments-2.6.1:
#       Successfully uninstalled Pygments-2.6.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 markdown-it-py-2.2.0 mdurl-0.1.2 onnx-1.13.1 onnx2tf-1.7.4 onnx_graphsurgeon-0.3.26 onnxruntime-1.14.0 onnxsim-0.4.17 protobuf-3.20.3 pybind11-2.10.3 pygments-2.14.0 rich-13.3.1 sng4onnx-1.0.1 sounddevice-0.4.6 tflite_support-0.4.3
#
# requirements: 7 packages updated per ('onnx', 'onnx2tf', 'sng4onnx', 'onnxsim', 'onnx_graphsurgeon', 'tflite_support', 'onnxruntime')
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.11.0...
#
# ONNX: starting export with onnx 1.13.1...
# [Errno 2] No such file or directory: '/usr/local/lib/python3.8/dist-packages/protobuf-3.19.6.dist-info/METADATA'
# ONNX: simplifying with onnxsim 0.4.17...
# ONNX: export success ✅ 1.3s, saved as yolov8n.onnx (12.2 MB)
#
# TensorFlow SavedModel: running onnx2tf -i yolov8n.onnx -o yolov8n_saved_model --non_verbose
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# 2023-02-23 11:27:48.425322: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# TensorFlow SavedModel: export success ✅ 54.7s, saved as yolov8n_saved_model (30.6 MB)
# TensorFlow Lite: export success ✅ 0.0s, saved as yolov8n_saved_model/yolov8n_float32.tflite (12.2 MB)
#
# Export complete (55.1s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolov8n_saved_model/yolov8n_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=yolov8n_saved_model/yolov8n_float32.tflite imgsz=640 data=coco.yaml
# Visualize:       https://netron.app

# %%
# !git clone https://github.com/tensorflow/examples.git
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 22971, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 22971 (delta 46), reused 115 (delta 29), pack-reused 22814
# Receiving objects: 100% (22971/22971), 42.11 MiB | 14.54 MiB/s, done.
# Resolving deltas: 100% (12581/12581), done.
# Updating files: 100% (2762/2762), done.

# %%
# !cd examples
# !git sparse-checkout init --cone
# !git sparse-checkout set lite/examples/object_detection/android
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
