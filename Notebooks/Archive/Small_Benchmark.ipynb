# %% [markdown]
# <font size=7> <center> Benchmark - Yolov8 Small</font></br>

# %% [markdown]
# # 1- Setup

# %%
# This line contains my github token. Please do not share it with anyone
# !git clone https://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@github.com/TKovaks78//Sign_Language_Translation_with_Yolov8.git
# Install requirements
# !pip install -r requirements.txt
# Install Ultralytics
# !pip install ultralytics
# Install clearML
# !pip install clearml
# Check GPU
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.42 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.3/78.2 GB disk)

# %%
# Import libraries
from clearml import Task
from ultralytics import YOLO
import matplotlib.pyplot as plt
from matplotlib.image import imread
import pandas as pd
import os

# %%
# Save models on clearML
# %env CLEARML_WEB_HOST=https://app.clear.ml
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=1XQ9HTBHM5TXCMJCF00W
# %env CLEARML_API_SECRET_KEY=LN6gjflJlyED9HOgyyG3F4G1DMXiRr1FKCi8tXwL7MhSUvMP5e
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=1XQ9HTBHM5TXCMJCF00W
# env: CLEARML_API_SECRET_KEY=LN6gjflJlyED9HOgyyG3F4G1DMXiRr1FKCi8tXwL7MhSUvMP5e

# %% [markdown]
# # 2. Train

# %%
# Define main folder path
path = "/content/Sign_Language_Translation_with_Yolov8"

# Define yaml file path 
yaml_path = os.path.join(path, "data/", "data.yaml")

# Define experience name
exp_name = "benchmark_small"

project_name = "DL_-_Sign_Detection" # DO NOT CHANGE THE PROJECT NAME

# %%
# Load a model
yolo_model = YOLO("yolov8s.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
#   0%|          | 0.00/21.5M [00:00<?, ?B/s]

# %%
task = Task.init(project_name = project_name, # DO NOT CHANGE PROJECT NAME
                 task_name=exp_name) # Name your experience
# Out:
# ClearML Task: created new task id=c908e64253dc4b7283ebd5c8791d1fba
# ClearML results page: https://app.clear.ml/projects/c6ca2057e9f140d38f5fc76e83cf8781/experiments/c908e64253dc4b7283ebd5c8791d1fba/output/log
# 2023-02-20 13:53:43,871 - clearml.Task - INFO - Storing jupyter notebook directly as code

# %%
# Train the model
yolo_model.train(data= yaml_path,
            project=project_name, 
            epochs=50,   
            name=exp_name)
# Out:
# Ultralytics YOLOv8.0.42 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/Sign_Language_Translation_with_Yolov8/data/data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=DL_-_Sign_Detection, name=benchmark_small, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, min_memory=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, split=val, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=DL_-_Sign_Detection/benchmark_small
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
#   0%|          | 0.00/755k [00:00<?, ?B/s]
# Overriding model.yaml nc=80 with nc=26
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2126110  ultralytics.nn.modules.Detect                [26, [128, 256, 512]]
# Model summary: 225 layers, 11145662 parameters, 11145646 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.util has been moved to tensorflow.python.checkpoint.checkpoint. The old module will be deleted in version 2.11.
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/Sign_Language_Translation_with_Yolov8/data/train/labels... 508 images, 0 backgrounds, 0 corrupt: 100%|██████████| 508/508 [00:00<00:00, 2194.29it/s]
# train: New cache created: /content/Sign_Language_Translation_with_Yolov8/data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/Sign_Language_Translation_with_Yolov8/data/valid/labels... 104 images, 0 backgrounds, 0 corrupt: 100%|██████████| 104/104 [00:00<00:00, 2350.69it/s]
# val: New cache created: /content/Sign_Language_Translation_with_Yolov8/data/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to DL_-_Sign_Detection/benchmark_small
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.16G      1.257      6.333      1.662         23        640: 100%|██████████| 32/32 [00:27<00:00,  1.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:03<00:00,  1.10it/s]
#                    all        104        104       0.27      0.234      0.107     0.0862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.98G     0.8816      3.286      1.362         28        640: 100%|██████████| 32/32 [00:20<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.13it/s]
#                    all        104        104      0.191       0.55      0.279      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.98G     0.8419      2.578      1.278         30        640: 100%|██████████| 32/32 [00:20<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.13it/s]
#                    all        104        104      0.273      0.526       0.42      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.98G     0.8597      2.344      1.287         28        640: 100%|██████████| 32/32 [00:18<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.12it/s]
#                    all        104        104      0.496      0.474      0.454      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.98G     0.8638      2.105      1.252         28        640: 100%|██████████| 32/32 [00:18<00:00,  1.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.54it/s]
#                    all        104        104      0.521      0.579      0.535       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.98G     0.8682      1.982      1.253         26        640: 100%|██████████| 32/32 [00:20<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00
/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.51it/s]
#                    all        104        104      0.911      0.862      0.959      0.858
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.98G        0.6     0.7219      1.082         24        640: 100%|██████████| 32/32 [00:18<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
#                    all        104        104       0.93      0.903       0.96       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.98G     0.6303     0.7665      1.117         18        640: 100%|██████████| 32/32 [00:18<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.02it/s]
#                    all        104        104      0.944       0.89      0.976      0.883
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.98G     0.5749     0.7044       1.06         20        640: 100%|██████████| 32/32 [00:18<00:00,  1.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.55it/s]
#                    all        104        104      0.909      0.933      0.979       0.89
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      4.98G     0.4188     0.3668     0.9758         12        640: 100%|██████████| 32/32 [00:13<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.15it/s]
#                    all        104        104      0.905      0.893      0.984       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      4.98G     0.4043     0.3403     0.9668         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.13it/s]
#                    all        104        104      0.899      0.888       0.96      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      4.98G     0.4048     0.3458     0.9714         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.14it/s]
#                    all        104        104      0.914      0.887      0.951      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      4.98G     0.3885     0.3289     0.9489         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.18it/s]
#                    all        104        104       0.92      0.888      0.965      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      4.98G     0.3807     0.2944      0.949         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.16it/s]
#                    all        104        104      0.885      0.895      0.953      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      4.98G     0.3801     0.3101     0.9554         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.16it/s]
#                    all        104        104      0.931      0.928      0.976      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      4.98G     0.3692     0.2961     0.9512         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.07it/s]
#                    all        104        104       0.95       0.94      0.979      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      4.98G     0.3591      0.287     0.9438         12        640: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.11it/s]
#                    all        104        104      0.925      0.921      0.978      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      4.98G     0.3542     0.2777     0.9422         12        640: 100%|██████████| 32/32 [00:12<00:00,  2.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.14it/s]
#                    all        104        104       0.95      0.911      0.978      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      4.98G     0.3459     0.2676     0.9249         12        640: 100%|██████████| 32/32 [00:11<00:00,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:04<00:00,  1.20s/it]
#                    all        104        104      0.925       0.94      0.984        0.9
#
# 50 epochs completed in 0.361 hours.
# Optimizer stripped from DL_-_Sign_Detection/benchmark_small/weights/last.pt, 22.5MB
# Optimizer stripped from DL_-_Sign_Detection/benchmark_small/weights/best.pt, 22.5MB
#
# Validating DL_-_Sign_Detection/benchmark_small/weights/best.pt...
# Ultralytics YOLOv8.0.42 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 11135646 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:03<00:00,  1.08it/s]
#                    all        104        104      0.924       0.94      0.984        0.9
#                      A        104          3          1      0.756      0.995      0.952
#                      B        104          3      0.921          1      0.995      0.883
#                      C        104          3      0.935          1      0.995      0.895
#                      D        104          3          1      0.452      0.863       0.69
#                      E        104          4      0.937          1      0.995      0.852
#                      F        104          4      0.754          1      0.945      0.873
#                      G        104          4          1      0.839      0.995        0.9
#                      H        104          4      0.806          1      0.995      0.953
#                      I        104          4      0.934          1      0.995      0.935
#                      J        104          8          1      0.816      0.995      0.816
#                      K        104          4      0.945          1      0.995      0.995
#                      L        104          4      0.869          1      0.995      0.959
#                      M        104          4      0.935          1      0.995      0.922
#                      N        104          4          1      0.958      0.995       0.91
#                      O        104          4      0.901          1      0.995      0.965
#                      P        104          4      0.988          1      0.995      0.792
#                      Q        104          4      0.953          1      0.995      0.753
#                      R        104          4          1      0.931      0.995      0.959
#                      S        104          4      0.789          1      0.995      0.972
#                      T        104          4      0.868       0.75      0.888      0.818
#                      U        104          4      0.934          1      0.995      0.995
#                      V        104          4      0.908          1      0.995      0.953
#                      W        104          4       0.96          1      0.995       0.95
#                      X        104          4      0.903          1      0.995      0.922
#                      Y        104          4          1      0.951      0.995      0.884
#                      Z        104          4      0.796          1      0.995      0.903
# Speed: 1.9ms preprocess, 5.8ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to DL_-_Sign_Detection/benchmark_small
# 2023-02-20 14:16:19,410 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/DL_-_Sign_Detection/benchmark_small.c908e64253dc4b7283ebd5c8791d1fba/models/best.pt
# 2023-02-20 14:16:22,670 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/DL_-_Sign_Detection/benchmark_small.c908e64253dc4b7283ebd5c8791d1fba/models/best.pt

# %% [markdown]
# <font size =2><u>Note:</u> to change any parameter you just have to add parameter_name=value. The only mandatory parameter is data</br>
# For example:
#
# ```
# # Train the model
# results_baseline = model.train(data= yaml_path,
#                               momentum = 0.9
#                               lrf = 0.0001)
# ```
# <font size =2>Please refer to the [configuration file](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/yolo/cfg/default.yaml)

# %% [markdown]
# # 3. Results

# %%
# Loss
img = imread(os.path.join(project_name, exp_name, "results.png"))
plt.figure(figsize=(14,12))
plt.imshow(img)
plt.show()

# %%
# Confusion matrix
img = imread(os.path.join(project_name, exp_name,"confusion_matrix.png"))
plt.figure(figsize=(14,12))
plt.imshow(img)
plt.show()

# %%
# top mAP50-95 score
df = pd.read_csv(os.path.join(project_name, exp_name,"results.csv"))
max_map50_index = df['    metrics/mAP50-95(B)'].idxmax()
result = df.loc[max_map50_index]
result
# Out:
#                   epoch    49.000000
#          train/box_loss     0.345850
#          train/cls_loss     0.267650
#          train/dfl_loss     0.924850
#    metrics/precision(B)     0.924890
#       metrics/recall(B)     0.940380
#        metrics/mAP50(B)     0.983880
#     metrics/mAP50-95(B)     0.900120
#            val/box_loss     0.454900
#            val/cls_loss     0.349230
#            val/dfl_loss     1.000300
#                  lr/pg0     0.000496
#                  lr/pg1     0.000496
#                  lr/pg2     0.000496
# Name: 49, dtype: float64

# %%
# Way around to avoid error when saving results
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# Save results
# Write your experience name
from google.colab import files
# !zip -r results.zip /content/DL_-_Sign_Detection/benchmark_small
files.download("results.zip")
# Out:
#   adding: content/DL_-_Sign_Detection/benchmark_small/ (stored 0%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/R_curve.png (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/weights/ (stored 0%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/weights/last.pt (deflated 8%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/weights/best.pt (deflated 8%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch1282.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/args.yaml (deflated 51%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/PR_curve.png (deflated 23%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/P_curve.png (deflated 8%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch1.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/F1_curve.png (deflated 6%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch1_labels.jpg (deflated 10%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch1280.jpg (deflated 11%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/results.png (deflated 8%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch1_pred.jpg (deflated 10%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch2.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch2_pred.jpg (deflated 12%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch0_pred.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch1281.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/confusion_matrix.png (deflated 18%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/results.csv (deflated 84%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch0_labels.jpg (deflated 9%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/val_batch2_labels.jpg (deflated 12%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/train_batch0.jpg (deflated 3%)
#   adding: content/DL_-_Sign_Detection/benchmark_small/events.out.tfevents.1676901232.7e87df9359fd.413.0 (deflated 71%)
